# %%
from pathlib import Path
import requests
import json
import re
from tqdm import tqdm
from datetime import datetime, timedelta
import time
from random import uniform

settings = json.loads(Path('../../../settings.json').read_text())preprocessed_data_path = Path(settings['preprocessed_data_path'])data_path = Path('.').resolve()data_name = data_path.namesource_name = data_path.parent.namepreprocessed_dir = preprocessed_data_path/source_name/data_namesource_data_dir = preprocessed_dir/'preprocessed'
splits = ['train', 'valid']
tasks = ['지식검색 대화', '질의응답 근거 생성']
task_data_dir = preprocessed_dir/'preprocessed_task'
task_data_dir.mkdir(exist_ok=True)
for task in tasks:
    task_path = task_data_dir/task
    task_path.mkdir(exist_ok=True)
    
#### prepare for task preprocess
def convert_str_to_date(str_date):
    try:
        str_date = int(float(str_date))
        date = datetime(1900, 1, 1) + timedelta(days=str_date - 2)
        date = date.strftime('%Y-%m-%d')
    except:
        return str_date
    return date

MIN_DELAY = 3.5
MAX_DELAY = 5.5


pattern = r'\[([^]]+)\]\(([^)]+)\)'
def get_text_from_url_with_jina_ai(url_source):
    if 'http://www.upinews.kr' in url_source:
        url_source = url_source.replace('http://www.upinews.kr', 'http://www.kpinews.kr')
    retries = 0
    max_retries = 3
    need_markdown = False
    headers = {
        "Accept": "application/json",
        # "Authorization": "Bearer jina_204693c0a0224c039ee7e31a9972d707v-uzqbiH_E_mh3bA159qTiaXxcK2"
        # "Authorization": "Bearer jina_a31367691f454e63875eeaf4c9dc204aivQ8TCnfu7spUuwwyAVUt1UplH1U"
    }
    response = None
    print(url_source, end=' ')
    while retries < max_retries:
        if need_markdown:
            if 'X-Return-Format' in headers and headers['X-Return-Format'] == "markdown":
                headers['X-Return-Format'] = "html"
            else:
                headers['X-Return-Format'] = "markdown" 
        sleep_time = uniform(MIN_DELAY, MAX_DELAY)
        print(f"Sleeping for {sleep_time} seconds..., {headers}")
        time.sleep(sleep_time)
        try:
            url_template = "https://r.jina.ai/{}"
            url = url_template.format(url_source)
            response = requests.get(url, headers=headers, timeout=3600)
            if not response.text:
                print('no text', retries, end=' ')
                retries += 1
                need_markdown = True
                continue
            result = json.loads(response.text)
            if result['code'] >= 400:
                print('code 400', retries, end=' ')
                retries += 1
                need_markdown = True
                continue
            result = result['data']
            result['url'] = url_source
            if 'title' in result:
                print(result['title'])
            text = result['content']
            cleaned_text = re.sub(pattern, r'\1', text)
            if len(cleaned_text) < 30:
                print('short text', retries, end=' ')
                retries += 1
                need_markdown = True
                continue
            result['content'] = cleaned_text
            return result
        except Exception as e:
            print(f"Request failed (retry {retries}/{max_retries}): {e}")
            #if response is not None:
            #    print(response.text)
            retries += 1
            need_markdown = True
            
        #     retries += 1
        #     delay = min(MAX_DELAY, 0.3 * (2 ** retries))
        #     print(f"Request failed (retry {retries}/{max_retries}): {e}")
        #     print(f"Waiting {delay} seconds before retrying...")
        #     time.sleep(delay + uniform(MIN_DELAY, MAX_DELAY))
    return None

tools = [
    {
        'name': 'retrieve_reference_texts',
        'description': 'Retrieve reference texts needed to respond to conversations',
        'parameters': {
            'type': 'object',
            'properties': {
                'search_query': {
                    'type': 'string',
                    'description': 'The search query to retrieve reference texts'},
                'conversations': {
                    'type': 'array',
                    'items': {'type': 'string'},
                    'description': 'The conversations to retrieve reference texts'}
            },
            'required': ['search_query', 'conversations']
        }
    }
]
function_call = {'name': 'retrieve_reference_texts', 'arguments': {'search_query': '', 'conversations': []}}
role_dict = {
    '질문자' : 'human',
    '전문가' : 'gpt',
}

#### prepare for task preprocess end
doc_dict = {}
doc_path = task_data_dir/'knowledge_search_doc.jsonl'
for doc in doc_path.open().readlines():
    if doc:
        doc = json.loads(doc)
        doc_dict[doc['url']] = doc['content']
doc_file = doc_path.open('a', encoding='utf-8')

#### task preprocess
for split in splits:
    source_data_dir_split = source_data_dir/split
    task_files = [(task_data_dir/task/f'{split}.jsonl').open('w', encoding='utf-8') for task in tasks]
    for source_data in tqdm(list(source_data_dir_split.iterdir()), desc=split):
        source_data = source_data.open()
        for line in source_data.readlines():
            line = json.loads(line)
            
            #### data preprocess
            utterances = line['utterances']
            utterances = [utt for utt in utterances if utt['terminate'] == False]
            no_context = False
            for utt in utterances:
                if url:=utt['search_URL']:
                    if (url not in doc_dict) or (not doc_dict[url]):
                        data = get_text_from_url_with_jina_ai(url)
                        if data:
                            doc_dict[url] = data['content']
                            if data['content']:
                                doc_file.write(json.dumps(data, ensure_ascii=False)+'\n')
                        else:
                            no_context = True
                if no_context:
                    break
                    
                if reference_text := utt['reference_text']:
                    utt['reference_text'] = [t['value'] for t in reference_text]
                    
                if reference_date := utt['reference_date']:
                    utt['reference_date'] = convert_str_to_date(reference_date)
            
            if no_context:
                continue
            #### data preprocess end 
            continue

            #### 지식검색 대화
            data = {'conversations': [], 'tools':json.dumps(tools)}
            ## preprocess data from line
            for utt in utterances:
                role = role_dict[utt['role']]
                text = utt['text']
                if role == 'human':
                    data['conversations'].append({'from': role, 'value': text})
                elif role == 'gpt':
                    if search_url:=utt['search_URL']:
                        function_call['arguments']['search_query'] = utt['search_query']
                        function_call['arguments']['conversations'] = [u['value'] for u in data['conversations'] if u['from'] in ['human', 'gpt']]
                        data['conversations'].append({'from': 'function_call', 'value': json.dumps(function_call, ensure_ascii=False)})
                        reference_texts = utt['reference_text']
                        data['conversations'].append({'from': 'observation', 'value': json.dumps({'reference_texts': reference_texts}, ensure_ascii=False)})
                        
                        #### 질의응답 근거 생성
                        inner_data = {'input': {}, 'output': {}}
                        ## preprocess data from line
                        inner_data['input']['search_query'] = utt['search_query']
                        inner_data['input']['conversations'] = function_call['arguments']['conversations']
                        inner_data['input']['document'] = doc_dict[search_url]                            
                        inner_data['output']['reference_texts'] = reference_texts
                        ## preprocess data from line end
                        task_files[1].write(json.dumps(inner_data, ensure_ascii=False)+'\n')
                        # print(json.dumps(inner_data, indent=4, ensure_ascii=False))
                        #### 질의응답 근거 생성 end
                            
                    data['conversations'].append({'from': role, 'value': text})
                
            ## preprocess data from line end
            task_files[0].write(json.dumps(data, ensure_ascii=False)+'\n')
            # print(json.dumps(data, indent=4, ensure_ascii=False))
            #### 지식검색 대화 end
            
    #         break
    #     break
    # break

    for path in task_files:
        path.close()     
doc_file.close() 
        
#### task preprocess end
# Out:
# train:   0%|          | 0/10 [00:00<?, ?it/s]
# http://www.kpinews.kr/newsView/upi202201110043 Sleeping for 4.12535401122836 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.879233213376942 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.6538573428520005 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.apparelnews.co.kr/news/news_view/?idx=187514 Sleeping for 4.300171888879667 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.523571198783568 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.8574184618491945 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.kpinews.kr/newsView/upi202103310020 Sleeping for 4.511132742291921 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.421160968725308 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.385682445572697 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://zine.istyle24.com/Fashion/FashionView.aspx?Idx=56194&Menu=12&_C_=23069 Sleeping for 4.903525196164957 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.843406351435617 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.832683229658442 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://allways.smotor.com/%EC%A7%80%EA%B8%88%EC%9D%80-suv-%EC%8B%9C%EB%8C%80-suv%EB%8A%94-%EC%99%9C-%EC%9D%B8%EA%B8%B0-%EC%9E%88%EC%9D%84%EA%B9%8C/ Sleeping for 4.451559867417049 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.900842571933505 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.76323029891468 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.apparelnews.co.kr/news/news_view/?idx=189448 Sleeping for 5.067085106841057 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.912840299026777 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.7477140820406305 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.wedding21news.co.kr/news/articleView.html?idxno=232026 Sleeping for 4.623234832278891 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.291625240269351 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.269547339307997 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.kpinews.kr/newsView/upi201904200017?oldid=1065601676618313 Sleeping for 3.8414270027705166 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.082204059147211 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.490960940464694 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.apparelnews.co.kr/news/news_view/?idx=189574 Sleeping for 5.411431475827398 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.72577275046251 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.498818449589388 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.kpinews.kr/newsView/upi202201070057 Sleeping for 4.095670621055897 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.222550358135889 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.0383467382533755 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.kwnews.co.kr/page/view/2020051200000000061 Sleeping for 5.426612958182485 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.852195749266041 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.2148312480365835 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.olivenote.co.kr/news/articleView.html?idxno=10502 Sleeping for 4.783289333132679 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.083481985260998 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.8480344754854072 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.goodkyung.com/news/articleView.html?idxno=75936 Sleeping for 5.094210109236537 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.809571734584729 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7032900433221796 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.newsworks.co.kr/news/articleView.html?idxno=610245 Sleeping for 4.8748013975712485 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.681192271741445 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.9165639442332205 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.goodkyung.com/news/articleView.html?idxno=167411 Sleeping for 4.718674044225914 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.280862788631649 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.593457863359598 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20190227000123 Sleeping for 5.226545418651638 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.626768501370438 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.374286481373888 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.cvinfo.com/news/articleView.html?idxno=21837 Sleeping for 4.400173227295969 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.311736899646684 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.294823708127751 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.codingworldnews.com/news/articleView.html?idxno=11653 Sleeping for 3.798173723836495 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.349099401270094 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.957199293721551 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.daenews.co.kr/news/view.php?no=17118 Sleeping for 4.766987526299978 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.911578656950448 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.423884580809781 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://zine.istyle24.com/Star/StarView.aspx?Idx=25324&Menu=3&_C_=23069 Sleeping for 4.246325863297979 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.022553075716331 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.059678611889938 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.olivenote.co.kr/news/articleView.html?idxno=3184 Sleeping for 3.5984330463500402 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.6005541941683044 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.5789043281091235 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.kpinews.kr/newsView/upi202202090056 Sleeping for 5.211168720420492 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.698455778805765 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.615520028674966 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.wikileaks-kr.org/news/articleView.html?idxno=130362 Sleeping for 3.5141030176487336 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.075529578317543 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.766990565890605 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.knun.net/news/article.html?no=14575 Sleeping for 3.5514401207184534 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.508590210353062 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.854410537538864 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220427000143 Sleeping for 4.530586027500112 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.323812635762933 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.490205740656359 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.newsearth.kr/news/articleView.html?idxno=1220 Sleeping for 3.854300651898283 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.9326740387211743 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7746371284308884 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://zine.istyle24.com/Fashion/FashionView.aspx?Idx=54861&Menu=4&_C_=23069 Sleeping for 4.583516793775102 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.144460893069274 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.454921687651938 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.kwnews.co.kr/page/view/2020053100000000118 Sleeping for 4.451094145926284 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.102732417293579 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.0766655006849435 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.newsworks.co.kr/news/articleView.html?idxno=593850 Sleeping for 5.441470987202376 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.5456415968916977 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.5681945633231558 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20221004000044 Sleeping for 4.268672559025337 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.186151641357621 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.222589241184142 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20211015000189 Sleeping for 4.948757167551486 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.6914200379982405 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.26817002321572 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20180504000039 Sleeping for 4.112518236129773 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.2567744812150385 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.7738790211574385 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://zine.istyle24.com/Beauty/BeautyView.aspx?Idx=59961&Menu=1&_C_=23069 Sleeping for 3.516530781901711 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.24961317513719 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.473326298818115 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.smartlifetv.co.kr/news/articleView.html?idxno=273 Sleeping for 4.092903911942304 seconds..., {'Accept': 'application/json'}
#
# short text 0 Sleeping for 3.8687514776604557 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
#
# short text 1 Sleeping for 5.215961399083799 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): 'content'
# https://www.wedding21news.co.kr/news/articleView.html?idxno=254595 Sleeping for 4.604589330903691 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.524202358408357 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.862736860337983 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.ujeil.com/news/articleView.html?idxno=314265 Sleeping for 4.005275495427229 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.278785510960616 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.317800728253148 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20221019000104 Sleeping for 5.212736350920661 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.2037708556755415 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.7202000501068797 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.digitaltoday.co.kr/news/articleView.html?idxno=256222 Sleeping for 3.6646182979415283 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.164910956024633 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.574513277765335 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.tradetimes.co.kr/news/articleView.html?idxno=11018 Sleeping for 4.765268128629514 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.757460408842692 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.631620859971161 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.codingworldnews.com/news/articleView.html?idxno=10431 Sleeping for 4.831694335144863 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.9010715901357615 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.140520429052126 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://lk.asiae.co.kr/article/2020061114123439109 Sleeping for 4.862037235432082 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.4741253920028985 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.438936117125724 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://zine.istyle24.com/Fashion/FashionView.aspx?Idx=49604&Menu=12&_C_=23069 Sleeping for 4.404614046267043 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.230142456763236 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7172329175691723 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.mdtoday.co.kr/mdtoday/index.html?no=418362 Sleeping for 3.9370142768065843 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.384540117445844 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.977038259853596 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://news.heraldcorp.com/view.php?ud=20140516000749 Sleeping for 3.87413020002686 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.917366856676746 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.8559283063397025 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20200626000148 Sleeping for 4.774029921994582 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.406365829976453 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.115906346955541 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://gametoc.hankyung.com/news/articleView.html?idxno=56030 Sleeping for 5.318709874649202 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.7645590434626053 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.096928078897665 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://zine.istyle24.com/Beauty/BeautyView.aspx?Idx=58735&Menu=1&_C_=23069 Sleeping for 4.481955224836274 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.645939179871063 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.302804786156419 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.dt.co.kr/contents.html?article_no=2014081702109932742001 Sleeping for 4.81361128531712 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.362335598947076 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.422454659105659 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20190926000087 Sleeping for 3.678287868102186 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.671921124070193 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.851004771426239 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20210322000093 Sleeping for 4.806459031063853 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.600447317210708 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.698459078382073 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220616000063 Sleeping for 4.425446539288614 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.282748605959304 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.828533542116471 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/201310170285 Sleeping for 4.003884040361545 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.6842827099278317 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.968053117699734 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220914000212 Sleeping for 4.748337289712615 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.456196162988333 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.878703014735586 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://evpost.donga.com/wp/%EC%8B%A4%EC%9A%A9%EC%84%B1%EC%9D%B4-%EB%8F%8B%EB%B3%B4%EC%9D%B4%EB%8A%94-%ED%95%98%EC%9D%B4%EB%B8%8C%EB%A6%AC%EB%93%9C-suv-%ED%98%BC%EB%8B%A4-%EB%89%B4-cr-v-%ED%95%98%EC%9D%B4%EB%B8%8C%EB%A6%AC/ Sleeping for 4.507097779823951 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.3603526843320495 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.299020725519441 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://zine.istyle24.com/Feature/FeatureView.aspx?Idx=27437&Menu=10&_C_=23069 Sleeping for 5.438761991540558 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.421872851116769 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.36767705085997 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20190207000041 Sleeping for 3.5115288328853342 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.431953793841863 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.0238985820942 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220923000092 Sleeping for 3.8293459234526948 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.224613903636938 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.740421720093388 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.healtip.co.kr/news/articleView.html?idxno=314 Sleeping for 5.117309477452608 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.8275531764849147 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.474008365530676 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.newsworks.co.kr/news/articleView.html?idxno=595102 Sleeping for 5.217253712304491 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.76993818608659 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.9848804658002286 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.snunews.com/news/articleView.html?idxno=18866 Sleeping for 4.503210269673245 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.2685093832075065 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.423953632167361 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20190605000056 Sleeping for 5.297788182078984 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.943541429626391 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.116603406892812 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.cartvnews.com/news/articleView.html?idxno=613460 Sleeping for 4.491940697097846 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.73661062937626 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.947781184228493 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.apparelnews.co.kr/news/news_view/?cat=CAT127&page=&idx=201033&searchKey=&searchWord= Sleeping for 4.634205155772462 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.46944886345797 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.293692812518388 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://zine.istyle24.com/Beauty/BeautyView.aspx?Idx=58483&Menu=1&_C_=23069 Sleeping for 3.8792450161092784 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.868107800737091 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.840891297009936 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20220324000251 Sleeping for 4.523514507628645 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.23240809506188 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.8969285065833468 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220615000061 Sleeping for 3.9596245679009154 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.840085089008323 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.27094117849854 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220912000058 Sleeping for 5.417996653684102 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.999760504448993 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.9535311928725525 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://jobsn.chosun.com/site/data/html_dir/2022/07/01/2022070102247.html?utm_source=naver&utm_medium=referral&utm_campaign=misaeng Sleeping for 5.028842356191588 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.173096930241833 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.8791497186655617 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.kpinews.kr/newsView/upi202210070037 Sleeping for 4.970762281490871 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.439430243668925 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.736550330117147 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20220929000070 Sleeping for 4.740098672794479 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.5177124555729815 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.827666075513932 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.cmcglr.com/news/articleView.html?idxno=1545 Sleeping for 3.831109901122082 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.451920943970231 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.324376165926561 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20210413000225 Sleeping for 3.6451516630273666 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.7847044759400505 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.451544664412509 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.kbmaeil.com/news/articleView.html?idxno=940117 Sleeping for 4.801114354781522 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.260745503809012 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7884819423063716 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.datasom.co.kr/news/articleView.html?idxno=101856 Sleeping for 4.201652227360949 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.950054607028152 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.448816830596757 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20200423000102 Sleeping for 5.338552827595708 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.301891529116898 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.077872053261616 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://zine.istyle24.com/Fashion/FashionView.aspx?Idx=44965&Menu=12&_C_=23069 Sleeping for 5.474981185625651 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.944146748914714 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.113008011703792 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20181016000076 Sleeping for 4.601055156343848 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.26507045013394 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.7472855872185855 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20150818000022 Sleeping for 3.9652023517825707 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.246171677877226 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.150485435124659 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.nbntv.kr/news/articleView.html?idxno=48337 Sleeping for 3.5523374724311507 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.948952502967647 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.9088467304793557 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/200712130106 Sleeping for 3.765691437738826 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.337754608472064 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.077549622773946 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://zine.istyle24.com/Fashion/FashionView.aspx?Idx=60844&Menu=12&_C_=23069 Sleeping for 4.3616929649592935 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.919645032232331 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7999554123844135 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20201105000025 Sleeping for 5.068283782601169 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.7773142992893556 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.788864038645968 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.goodkyung.com/news/articleView.html?idxno=172614 Sleeping for 4.072133159856493 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.637851560993517 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.024190425530573 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20221027000146 Sleeping for 3.7674523220072382 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.780132543215664 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.6307563015450866 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.goodkyung.com/news/articleView.html?idxno=143710 Sleeping for 4.483357450551859 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.5030054065384215 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.512026748009336 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20221010000073 Sleeping for 5.477754123177012 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.220350639891214 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.819279185788732 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220616000063 Sleeping for 3.980006492064918 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.888308485153852 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.138166254668274 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220428000057 Sleeping for 4.342970699259488 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.463070348069374 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.730483482352655 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220804000038 Sleeping for 4.830184551288919 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.326415756769778 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.8986145433356656 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20210209000165 Sleeping for 4.917472668410343 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.220942724966717 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.569421278772718 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220617000034 Sleeping for 5.3183337219774325 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.170444748994107 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.088149779410255 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220915000082 Sleeping for 3.881057321601518 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.015316778955716 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.062146092303895 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220915000082 Sleeping for 3.9260315044192042 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.859528827911627 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.106256135862332 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20221007000086 Sleeping for 3.6988632799922114 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.819916358134547 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.127582729588136 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.wedding21news.co.kr/news/articleView.html?idxno=252364 Sleeping for 4.04311602696003 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.318293416572729 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.123564313086563 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20221021000170 Sleeping for 3.818151020415775 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.742196124586134 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.310050256923684 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.kpinews.kr/newsView/upi201904180022?oldid=1065602658845384 Sleeping for 4.830130461248546 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.270656082187597 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.999503539675544 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20221006000060 Sleeping for 4.282883962132988 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.827847399271878 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.643623895843524 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.iusm.co.kr/news/articleView.html?idxno=933727 Sleeping for 3.7103788606984116 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.218000555328438 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.060071903246337 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.codingworldnews.com/news/articleView.html?idxno=4430 Sleeping for 5.020043997150529 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.8246046558122657 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.147814995517533 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220616000063 Sleeping for 4.3997519240353515 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.98243227090963 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.323134090178738 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.busan.com/view/busan/view.php?code=20181223000107 Sleeping for 5.137186073759251 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.130601196594165 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.8430835237844203 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20220630000096 Sleeping for 5.06877778069492 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.390345893186693 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.464830308371741 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20181010000109 Sleeping for 3.518171531052901 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.7271394975922245 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.241965520085265 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20210322000093 Sleeping for 5.053824286742258 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.472817428157787 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.269694513027782 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20211111000079 Sleeping for 3.719890357895914 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 5.076518464075711 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.351587247089039 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20220706000135 Sleeping for 3.7481083091974234 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.915143454524787 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.730835699351463 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.opinionnews.co.kr/news/articleView.html?idxno=69441 Sleeping for 5.041528869792634 seconds..., {'Accept': 'application/json'}
# ...
# https://www.etnews.com/20220622000221 Sleeping for 4.168586366397766 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.1097028904128425 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 5.464004542660843 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://knun.net/news/article.html?no=20348 Sleeping for 4.89310719171284 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.120907693616166 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.643513012981016 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://sports.hankooki.com/news/articleView.html?idxno=6487663 Sleeping for 5.471018566778392 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.120083512579871 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.011840134803317 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20220916000051 Sleeping for 4.072455544446409 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.614486514408478 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.6697245683479456 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20161103000246 Sleeping for 5.252597497730153 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 4.097270594608913 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.291013180463497 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20221003000145 Sleeping for 3.5335499246362794 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.564830810916189 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.629035952384147 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20210916000113 Sleeping for 5.039481926348424 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.6105317610924255 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.989600692513289 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.busan.com/view/busan/view.php?code=2022091318422603513 Sleeping for 4.824305616838081 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.9108696824923594 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.284196853282046 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.dt.co.kr/contents.html?article_no=2021020502109923053013&ref=naver Sleeping for 4.299834054775585 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.360068748105592 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.131949771675494 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.cctvnews.co.kr/news/articleView.html?idxno=213486 Sleeping for 3.841727124966262 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.713698628787222 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.880154458272232 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.idaegu.com/newsView/idg201907080045 Sleeping for 5.405018075863094 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.346030561296961 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7237217342848288 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://www.etnews.com/20200103000186 Sleeping for 3.967448816352407 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.9071136942951843 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.070561343560216 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 https://www.etnews.com/20190523000368 Sleeping for 4.60776959015341 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.978864212729106 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 3.93880312134956 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.ggilbo.com/news/articleView.html?idxno=885577 Sleeping for 5.233277115337338 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.956340125741885 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.985976977000411 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# https://jobsn.chosun.com/site/data/html_dir/2022/07/05/2022070501642.html Sleeping for 5.413239070324031 seconds..., {'Accept': 'application/json'}
# code 400 0 Sleeping for 3.670710310463804 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# code 400 1 Sleeping for 4.3421322004446905 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# code 400 2 http://www.gnnews.co.kr/news/articleView.html?idxno=480113 Sleeping for 3.9725280400477394 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.108412480380869 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.473744400713093 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.busan.com/view/busan/view.php?code=2022041714155177009 Sleeping for 4.902060816770178 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.825134539726726 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.229283912501754 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.safetimes.co.kr/news/articleView.html?idxno=86032 Sleeping for 3.541932980910034 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.371190954644385 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.876190792771705 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.m-i.kr/news/articleView.html?idxno=734621 Sleeping for 4.144142678952884 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.663758561362119 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.485782415542248 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://jmagazine.joins.com/monthly/view/329063 Sleeping for 5.111159743492042 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.399167809250068 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.571707088083937 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.readersnews.com/news/articleView.html?idxno=92036 Sleeping for 4.069433966558826 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.237675071215163 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.369821653482063 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.seoulwire.com/news/articleView.html?idxno=40814 Sleeping for 4.951687911122691 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7560969948233622 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.84571122069237 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://zine.istyle24.com/Fashion/FashionView.aspx?Idx=39956&Menu=12&_C_=23069 Sleeping for 3.6157121990666843 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.513058774198834 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.321576199271303 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.iusm.co.kr/news/articleView.html?idxno=304298 Sleeping for 4.109832834975301 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.514317094516853 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.121422041706011 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.koreahealthlog.com/news/articleView.html?idxno=32674 Sleeping for 4.88938368968857 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7452334920529173 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.7544698271841717 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.yeongjong.co.kr/news/articleView.html?idxno=1872 Sleeping for 3.50783205265445 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.940043440944347 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.5319232834838985 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.munhwa.com/news/view.html?no=2013012901032530048004 Sleeping for 4.029272681873062 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.891001706831064 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.887122021840122 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.smedaily.co.kr/news/articleView.html?idxno=232560 Sleeping for 5.402878336180071 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.522155336071506 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.3515129234745356 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.beyondpost.co.kr/view.php?ud=202005220952506702992c130dbe_30 Sleeping for 4.648308621310148 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.526671799892597 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.560660324736089 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.seniormaeil.com/news/articleView.html?idxno=26512 Sleeping for 3.7267486804495964 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.118388243241659 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.716868414057625 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.sisajournal.com/news/articleView.html?idxno=242203 Sleeping for 5.249893032523144 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.164134218986084 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 5.217821941165409 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)
# http://www.ngetnews.com/news/articleView.html?idxno=300856 Sleeping for 4.653001032352869 seconds..., {'Accept': 'application/json'}
# Request failed (retry 0/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 4.979772196847153 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'markdown'}
# Request failed (retry 1/3): Expecting value: line 1 column 1 (char 0)
# Sleeping for 3.5390161055024514 seconds..., {'Accept': 'application/json', 'X-Return-Format': 'html'}
# valid: 100%|██████████| 10/10 [2:25:46<00:00, 874.67s/it]
# Request failed (retry 2/3): Expecting value: line 1 column 1 (char 0)

# %%
for path in task_files:
    path.close()     
doc_file.close()
